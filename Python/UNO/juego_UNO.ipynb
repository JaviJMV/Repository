# %%
def primerejemplo(nombre, edad):
  # bloque de creación de variables
  direccion=input("Dame tu dirección: ")
  cp = int(input("Dame tu código postal: "))
  if cp >= 45000 and cp <= 45999:
    print("Esta usted en la delegación de Toledo.")
    if edad < 12:
      print("Tienes el autobus gratis.")
      op = input("¿Quieres soliciterlo?(si/no): ")
      if op == "si":
        print("--------------------------------")
        print("| CARNET DE AUTOBUS INFANTIL   |")
        print("| Nombre: "+nombre+" "*(21-len(nombre))+"|")
        print("| Edad: "+str(edad)+"                       |")
        print("| Toledo                       |")
        print("--------------------------------")
    elif edad < 18:
      print("Beber y fumar perjudican a las neuronas.")
    else:
      print("Ya puedes hacer lo que quieras, PAGAS IMPUESTOS!!")
  elif cp >= 13000 and cp <= 13999:
    print("Esta usted en la delegación de Ciudad Real.")
    if edad < 12:
      print("Tienes el autobus gratis.")
      op = input("¿Quieres soliciterlo?(si/no): ")
      if op == "si":
        print("--------------------------------")
        print("| CARNET DE AUTOBUS INFANTIL   |")
        print("| Nombre: "+nombre+" "*(21-len(nombre))+"|")
        print("| Edad: "+str(edad)+"                      |")
        print("| Ciudad Real                  |")
        print("--------------------------------")
    elif edad < 18:
      print("Beber y fumar perjudican a las neuronas.")
    else:
      print("Ya puedes hacer lo que quieras, PAGAS IMPUESTOS!!")
  else:
    print("No tengo competencia en su población.")
  return cp


def programaprincilap():
  nombre = input("dame nombre: ")
  edad = int(input("dame eddad: "))
  cp = primerejemplo(nombre, edad)
  print(nombre, edad, cp)


programaprincilap()
# Out:
# dame nombre: Luis
# dame eddad: 25
# Dame tu dirección: Jarama 12
# Dame tu código postal: 45004
# Esta usted en la delegación de Toledo.
# Ya puedes hacer lo que quieras, PAGAS IMPUESTOS!!
# Luis 25 45004

# %%
import random

baraja = ["R0","R1","R2","R3","R4","R5","R6","R7","R8","R9","B0","B1","B2","B3","B4","B5","B6","B7","B8","B9","Y0","Y1","Y2","Y3","Y4","Y5","Y6","Y7","Y8","Y9","G0","G1","G2","G3","G4","G5","G6","G7","G8","G9"]

jugador1 = []
jugador2 = []

def barajar_cartas(lista):
    random.shuffle(lista)
    return lista

def repartir_cartas(baraja):
    mano = []
    for i in range(7):
        mano.append(baraja.pop())
    return mano

def empieza_jugador():
    return random.randint(1, 2)

def turno_jugada(jugador, cartacentro, baraja):
    escogecarta = True
    while escogecarta:
        print(jugador)
        print("Carta central: ", cartacentro[-1])
        carta = input("¿Qué carta quieres escoger? (Ej:'R8') o pulsa intro para pasar").upper()
        if carta == "":
            if len(baraja) == 0:
                print("Empate")
                baraja += cartacentro[:-1]
                cartacentro = [cartacentro[-1]]
                break
            robacarta = baraja.pop()
            jugador.append(robacarta)
            print(jugador)
            print("Carta central: ", cartacentro[-1])
            carta = input("¿Qué carta quieres escoger? (Ej:'R8') o pulsa intro para pasar").upper()
        if carta == "":
            return jugador, cartacentro, baraja
        if carta[0] == cartacentro[-1][0] or carta[1] == cartacentro[-1][1]:
            cartacentro.append(carta)
            if carta in jugador:
                posicion = jugador.index(carta)
                jugador.pop(posicion)
                escogecarta = False
            else:
                print("No tienes esa carta")
                escogecarta = True
        else:
            print("Debes elegir una carta que coincida en color o número")
    return jugador, cartacentro, baraja

def juego_uno(jugador1, jugador2, baraja):
    baraja = barajar_cartas(baraja)
    jugador1 = repartir_cartas(baraja)
    jugador2 = repartir_cartas(baraja)
    cartacentro = [baraja.pop()]
    turno = empieza_jugador()
    if turno == 1:
      while len(jugador1) > 0 and len(jugador2) > 0:
        print("Turno jugador 1:")
        jugador1, cartacentro, baraja = turno_jugada(jugador1, cartacentro, baraja)
        print("Turno jugador 2:")
        jugador2, cartacentro, baraja = turno_jugada(jugador2, cartacentro, baraja)
        jugador2, cartacentro, baraja = turno_jugada(jugador2,cartacentro, baraja)
      if len(jugador1)==0:
        return "GANA jugador 1"
      if len(jugador2)==0:
        return "GANA jugador 2"
    if turno==2:
      while(len(jugador1)>0 and len(jugador2)>0):
        print("Turno jugador 2:")
        jugador2, cartacentro, baraja = turno_jugada(jugador2,cartacentro, baraja)
        print("Turno jugador 1:")
        jugador1, cartacentro, baraja = turno_jugada(jugador1,cartacentro, baraja)
      if len(jugador1)==0:
        return "GANA jugador 1"
      if len(jugador2)==0:
        return "GANA jugador 2"


juego_uno(jugador1,jugador2,baraja)
# Out:
# Turno jugador 2:
# ['R8', 'G5', 'R0', 'Y5', 'R5', 'B6', 'G1']
# Carta central:  G0
# ¿Qué carta quieres escoger? (Ej:'R8') o pulsa intro para pasarG1
# Turno jugador 1:
# ['G4', 'Y3', 'B1', 'G8', 'R7', 'G7', 'G3']
# Carta central:  G1
# ¿Qué carta quieres escoger? (Ej:'R8') o pulsa intro para pasarB1
# Turno jugador 2:
# ['R8', 'G5', 'R0', 'Y5', 'R5', 'B6']
# Carta central:  B1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-8146f19c38e4> in <cell line: 82>()
#      80
#      81
# ---> 82 juego_uno(jugador1,jugador2,baraja)
#
# <ipython-input-15-8146f19c38e4> in juego_uno(jugador1, jugador2, baraja)
#      71       while(len(jugador1)>0 and len(jugador2)>0):
#      72         print("Turno jugador 2:")
# ---> 73         jugador2, cartacentro, baraja = turno_jugada(jugador2,cartacentro, baraja)
#      74         print("Turno jugador 1:")
#      75         jugador1, cartacentro, baraja = turno_jugada(jugador1,cartacentro, baraja)
#
# <ipython-input-15-8146f19c38e4> in turno_jugada(jugador, cartacentro, baraja)
#      24         print(jugador)
#      25         print("Carta central: ", cartacentro[-1])
# ---> 26         carta = input("¿Qué carta quieres escoger? (Ej:'R8') o pulsa intro para pasar").upper()
#      27         if carta == "":
#      28             if len(baraja) == 0:
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.9/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
